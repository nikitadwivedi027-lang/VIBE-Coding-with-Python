# %% [markdown]
# ### User defined Basics

# %%
def calc_pizza_area():
    pi_val = 3.14159265

    pizza_diameter = 12.0
    pizza_radius = pizza_diameter / 2.0
    pizza_area = pi_val * pizza_radius * pizza_radius
    return pizza_area
print( '12. 0 inch pizza is' , calc_pizza_area(),'square inches.')
# Out:
# 12. 0 inch pizza is 113.09733540000002 square inches.

# %%
def  compute_square(num_to_square):
    return num_to_square * num_to_square

num_squared = compute_square(7)
print( '7 squared is ', num_squared)
# Out:
# 7 squared is  49

# %% [markdown]
# #### Multiple functions

# %%
def calc_pizza_volume(pizza_diameter, pizza_height):
    pi_val = 3.14159265
    pizza_radius = pizza_diameter / 2.0
    pizza_area = pi_val * pizza_radius * pizza_radius
    pizza_volume = pizza_area * pizza_height
    return pizza_volume
print( '12. 0 inch pizza with 1.5 inch height is', calc_pizza_volume(12.0, 1.5), 'cubic inches.')
print( '12. 0 inch pizza with 0.3 inch height is', calc_pizza_volume(12.0, 0.3), 'cubic inches.')
# Out:
# 12. 0 inch pizza with 1.5 inch height is 169.64600310000003 cubic inches.
# 12. 0 inch pizza with 0.3 inch height is 33.92920062 cubic inches.

# %% [markdown]
# ### Print functions

# %%
def print_summary(oid,items,price):
    print( 'Order' ,oid)
    print( 'Items', items)
    print( 'Total:', price)
print_summary( 1234, 3, 19.99)
# Out:
# Order 1234
# Items 3
# Total: 19.99

# %%
def print_menu():
    print("Today's Menu:")
    print(' 1) Ice cream')
    print(' 2) Ginger Rasam')
    print(' 3) Quit\n')
quit_program = False
while not quit_program:
    print_menu()
    choice = int(input('Enter choice: '))
    if choice == 3:
        print('Goodbye')
        quit_program = True
    else:
        print('Order: ', end='')
    if choice == 1:
        print('Ice cream')
    elif choice == 2:
        print('Ginger Rasam')
print()
# Out:
# Today's Menu:
#  1) Ice cream
#  2) Ginger Rasam
#  3) Quit
#
# Order: Ice cream
# Today's Menu:
#  1) Ice cream
#  2) Ginger Rasam
#  3) Quit
#
# Order: Ginger Rasam
# Today's Menu:
#  1) Ice cream
#  2) Ginger Rasam
#  3) Quit
#
# Goodbye

# %% [markdown]
# ### Dynamic typing

# %%
# Dynamic Typing
def add(x, y):
    return x+y
# passing integer as an argument
# sum of two integers
m = add(2,5)
print(m)
# Out:
# 7

# %%
# passing string as an argument
# concatenation Of two string
n = add('Anup ' ,'Kelkar')
print(n)
# Out:
# Anup Kelkar

# %% [markdown]
# ### Reasons for defining functions

# %%
feet_per_step = 3
steps_per_minute = 70.0
calories_per_minute_walking = 3.5

steps = int(input( 'Enter number Of steps walked:'))
print( ' Steps:', steps)

feet =steps * feet_per_step
print( ' Feet:', feet)
# Out:
#  Steps: 70
#  Feet: 210

# %%
minutes = steps / steps_per_minute
calories = minutes * calories_per_minute_walking
print( 'Calories: ' ,calories)
# Out:
# Calories:  3.5

# %%
def steps_to_feet(num_steps):
    feet_per_step = 3
    feet = num_steps * feet_per_step
    return feet

def steps_to_calories (num_steps):
    steps_per_minute = 70.0
    calories_per_minute_walking = 3.5
    minutes = num_steps/steps_per_minute
    calories = minutes*calories_per_minute_walking
    return calories

# %%
steps = int(input('Enter number of steps walked: '))
print('Steps: ', steps)
feet = steps_to_feet(steps)
print('Feet: ', feet)
calories = steps_to_calories(steps)
print('Calories: ', calories)
# Out:
# Steps:  85
# Feet:  255
# Calories:  4.25

# %%
steps = int(input('Enter number of steps walked: '))
calories = steps_to_calories(steps)
print('Calories: ', calories)
# Out:
# Calories:  1.25

# %% [markdown]
# #### Redundant code

# %%
pi_val = 3.14
pizza_diameter_1 = 12.0
circle_radius_1 = pizza_diameter_1/2.0
circle_area_1 = pi_val * circle_radius_1 * circle_radius_1

pizza_diameter_2 = 14.0
circle_radius_2 = pizza_diameter_2 / 2.0
circle_area_2 = pi_val * circle_radius_2 * circle_radius_2

total_pizza_area = circle_area_1 + circle_area_2

print('A 12 and 14 inch pizza has', end=' ')
print(f' {total_pizza_area:,.2f} ' , end='')
print( 'square inches combined.')
# Out:
# A 12 and 14 inch pizza has  266.90 square inches combined.

# %%
def calc_circle_area (circle_diameter):
    pi_val = 3.14
    circle_radius = circle_diameter / 2.0
    circle_area = pi_val*circle_radius*circle_radius
    return circle_area
pizza_diameter_1 = 12.0
pizza_diameter_2 = 14.0
total_pizza_area = calc_circle_area(pizza_diameter_1)+calc_circle_area (pizza_diameter_2)
print('A 12 and 14 inch pizza has', end=' ')
print(f'{total_pizza_area:.2f}', end=' ')
print('square inches combined.')
# Out:
# A 12 and 14 inch pizza has 266.90 square inches combined.

# %% [markdown]
# ### Mathematical Fucntions

# %%
CM_PER_INCH = 2.54
INCHES_PER_FOOT = 12

def height_US_to_cm(feet, inches) :
    total_inches = feet*INCHES_PER_FOOT + inches
    cm = total_inches * CM_PER_INCH
    return cm

i_feet = 6
i_inches = 4
centimeters = height_US_to_cm(i_feet,i_inches)
print( ' Centimeters : ' , centimeters)
# Out:
#  Centimeters :  193.04

# %% [markdown]
# ### Calling functions in expressions

# %%
def compute_square(num_to_square):
    return num_to_square * num_to_square

c2 = compute_square(7) + compute_square(9)
print('7 squared plus 9 squared is', c2)
# Out:
# 7 squared plus 9 squared is 130

# %% [markdown]
# ### Modular functions for mathematical expressions

# %%
import math

def calc_circular_base_area(radius):
    return math. pi * radius * radius

def calc_cylinder_volume(baseRadius, height):
    return calc_circular_base_area(baseRadius) * height

def calc_cylinder_surface_area(baseRadius, height) :
    return (2 * math.pi * baseRadius * height) + (2 * calc_circular_base_area(baseRadius))

radius = float(input('Enter base radius:'))
height = float(input ('Enter height:'))

print( 'Cylinder volume: ' + f' {calc_cylinder_volume(radius,height):.3f}')
print( 'Cylinder surface area:' + f'{calc_cylinder_surface_area(radius,height):.3f}')
# Out:
# Cylinder volume:  785.398
# Cylinder surface area:471.239

# %% [markdown]
# ### Function stubs

# %%
def steps_to_feet(num_steps) :
    feet_per_step = 3
    feet = num_steps * feet_per_step
    return feet

def steps_to_calories(num_steps):
    pass
steps = int(input( 'Enter number of steps walked:'  ))
print( ' Steps:', steps)

feet = steps_to_feet(steps)
print( ' Feet:', feet)
calories= steps_to_calories(steps)
print( 'Calories: ' ,calories)
# Out:
#  Steps: 251
#  Feet: 753
# Calories:  None

# %%
def steps_to_feet(num_steps) :
    feet_per_step = 3
    feet = num_steps * feet_per_step
    return feet

def steps_to_calories(num_steps):
    print('FIXME: Implement steps_to_calories function')
    return -1
steps = int(input( 'Enter number of steps walked:'  ))
print( ' Steps:', steps)

feet = steps_to_feet(steps)
print( ' Feet:', feet)
calories= steps_to_calories(steps)
print( 'Calories: ' ,calories)
# Out:
#  Steps: 251
#  Feet: 753
# FIXME: Implement steps_to_calories function
# Calories:  -1

# %% [markdown]
# ### Function with branches/loops

# %%
def calc_ebay_fee(sell_price):

  p50 =  0.13 # for amount $50 and lower
  p50_to_1000 =0.05 # for $50.01-$1000
  p1000 = 0.02  # for $ 1000.01 and h igher
  fee = 0.50 # fee to List item

  if sell_price <= 50:
    fee =fee + (sell_price*p50)
  elif sell_price <= 1000:
    fee = fee + (50*p50) + ((sell_price-50)*p50_to_1000)
  else:
    fee = fee + (50*p50) + ((1000-50)*p50_to_1000)\
              + ((sell_price-1000)*p1000)
  return fee

selling_price = float(input('Enter item selling price (ex: 65.00):'))
print('Selling price: $', selling_price)
print('eBay fee: $', calc_ebay_fee(selling_price))
# Out:
# Selling price: $ 0.0
# eBay fee: $ 0.5

# %% [markdown]
# ### Functions are objects

# %%
def print_human_head():
    print(' ||||| ')
    print(' ㅇㅇ')
    print(' >')
    print('    00000')
    return

# %%
def print_monkey_head():
    print('  .-"-._ ')
    print(' _/.-.-.\\\\_')
    print('( ( o o ) )')
    print(' |/  "  \\\\|')
    print('  \\\\ .-. / ')
    print('  / `"""`\\\\')
    return

# %%
def print_figure(face):
    face() # Print the face
    print('    |')
    print('  --|--')
    print(' /  |  \\\\')
    print('@   |   @')
    print('    |\'')
    print('   /|\\\\')
    print('  @   @')
    return

# %%
choice = int(input('Enter "1" to draw monkey, "2" for human:'))

if choice ==1:
    print_figure (print_monkey_head)
elif choice == 2:
    print_figure (print_human_head)
# Out:
#   .-"-._
#  _/.-.-.\\_
# ( ( o o ) )
#  |/  "  \\|
#   \\ .-. /
#   / `"""`\\
#     |
#   --|--
#  /  |  \\
# @   |   @
#     |'
#    /|\\
#   @   @

# %% [markdown]
# ### Scope of variables and functions

# %% [markdown]
# ## Local variable

# %%
centimeters_per_inch =  2.54
inches_per_foot = 12

def height_US_to_centimeters(feet, inches):
    total_inches = (feet * inches_per_foot) + inches # Total inches
    print('Total inches: ', total_inches)
    centimeters = total_inches * centimeters_per_inch
    print('Centimeters: ', centimeters)
    return centimeters

i_feet = int(input('Enter feet: '))
print( 'Feet: ' , i_feet)
i_inches = int(input( ' Enter inches:'))
print( 'Inches: ' , i_inches)
print( 'Centimeters: ' , height_US_to_centimeters(i_feet,i_inches))
# Out:
# Feet:  5
# Inches:  5
# Total inches:  65
# Centimeters:  165.1
# Centimeters:  165.1

# %% [markdown]
# ## Global variables

# %%
employee_name = 'N/A'
def get_name():

    name = input( ' Enter employee name: ' )
    print( ' Employee name: ' , name)
    employee_name = name
get_name ( )
print( ' Employee name: ' , employee_name)
# Out:
#  Employee name:  Nikita Dwivedi
#  Employee name:  N/A

# %%
employee_name = 'N/A'
def get_name():
    global employee_name
    name = input('Enter employee name: ')
    print('Employee name: ', name)
    employee_name = name
get_name ( )
print( ' Employee name: ' , employee_name)
# Out:
# Employee name:  Nikita dwivedi
#  Employee name:  Nikita dwivedi

# %%
employee_name = 'N/A'
get_name2()
print('Employee name:', employee_name)

def get_name2():
    global employee_name
    name = input('Enter employee name:')
    employee_name = name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 employee_name = 'N/A'
# ----> 2 get_name2()
#       3 print('Employee name:', employee_name)
#       5 def get_name2():
#
# NameError: name 'get_name2' is not defined

# %% [markdown]
# ### Namespaces

# %%
print('Initial global namespace: ')
print(globals())
# Out:
# Initial global namespace:
# {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, '__loader__': None, '__spec__': None, '__builtin__': <module 'builtins' (built-in)>, '__builtins__': <module 'builtins' (built-in)>, '_ih': ['', "def print_human_head():\n    print(' ||||| ')\n    print(' ㅇㅇ')\n    print(' >')\n    print('\n    00000\n    return", "def print_human_head():\n    print(' ||||| ')\n    print(' ㅇㅇ')\n    print(' >')\n    print('    00000')\n    return", 'def print_monkey_head():\n    print(\'.-"-.\')\n    print(\'/.-.-.\\\\_\')\n    print(\'((oo))\')\n    print(\'|/ " \\\\\\\')\n    print(\' \\\\.-./\')\n    print(\'/`"""`\\\\\')\n    return', 'def print_monkey_head():\n    print(\'  .-"-._ \')\n    print(\' _/.-.-.\\\\\\\\_\')\n    print(\'( ( o o ) )\')\n    print(\' |/  "  \\\\\\\\|\')\n    print(\'  \\\\\\\\ .-. / \')\n    print(\'  / `"""`\\\\\\\\\')\n    return', "def print_figure(face):\n    face() # Print the face\n    print('    |')\n    print('  --|--')\n    print(' /  |  \\\\\\\\')\n    print('@   |   @')\n    print('    |\\'')\n    print('   /|\\\\\\\\')\n    print('  @   @')\n    return", 'choice = int(input(\'Enter "1" to draw monkey, "2" for human:\'))\n\nif choice ==1:\n    print _ figure (print_monkey_head)\nelif choice == 2:\nprint _ figure (print_human_head)', 'choice = int(input(\'Enter "1" to draw monkey, "2" for human:\'))\n\nif choice ==1:\n    print_figure (print_monkey_head)\nelif choice == 2:\n    print_figure (print_human_head)', 'choice = int(input(\'Enter "1" to draw monkey, "2" for human:\'))\n\nif choice ==1:\n    print_figure (print_monkey_head)\nelif choice == 2:\n    print_figure (print_human_head)', "centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input('Enter feet: '))\ni_inches = int(input( ' Enter inches:'))\n\nprint( 'Centimeters: ' , height_US_to_centimeters(i_feet,i_inches))", "centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    print('Total inches: ', total_inches)\n    centimeters = total_inches * centimeters_per_inch\n    print('Centimeters: ', centimeters)\n    return centimeters\n\ni_feet = int(input('Enter feet: '))\nprint( 'Feet: ' , i_feet)\ni_inches = int(input( ' Enter inches:'))\nprint( 'Inches: ' , i_inches)\n\nprint( 'Centimeters: ' , height_US_to_centimeters(i_feet,i_inches))", "centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    print('Total inches: ', total_inches)\n    centimeters = total_inches * centimeters_per_inch\n    print('Centimeters: ', centimeters)\n    return centimeters\n\ni_feet = int(input('Enter feet: '))\nprint( 'Feet: ' , i_feet)\ni_inches = int(input( ' Enter inches:'))\nprint( 'Inches: ' , i_inches)\nprint( 'Centimeters: ' , height_US_to_centimeters(i_feet,i_inches))", "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)", "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    print( ' Employee name: ' , name)\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)", "employee_name = 'N/A'\ndef get_name():\n    global employee_name\n    name = input('Enter employee name: ')\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)", "employee_name = 'N/A'\ndef get_name():\n    global employee_name\n    name = input('Enter employee name: ')\n    print('Employee name: ', name)\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , emplo ...

# %%
my_var = "This is a variable"
print('\nCreated new variable') 
globals()
# Out:
# Created new variable
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   "def print_human_head():\n    print(' ||||| ')\n    print(' ㅇㅇ')\n    print(' >')\n    print('\n    00000\n    return",
#   "def print_human_head():\n    print(' ||||| ')\n    print(' ㅇㅇ')\n    print(' >')\n    print('    00000')\n    return",
#   'def print_monkey_head():\n    print(\'.-"-.\')\n    print(\'/.-.-.\\\\_\')\n    print(\'((oo))\')\n    print(\'|/ " \\\\\\\')\n    print(\' \\\\.-./\')\n    print(\'/`"""`\\\\\')\n    return',
#   'def print_monkey_head():\n    print(\'  .-"-._ \')\n    print(\' _/.-.-.\\\\\\\\_\')\n    print(\'( ( o o ) )\')\n    print(\' |/  "  \\\\\\\\|\')\n    print(\'  \\\\\\\\ .-. / \')\n    print(\'  / `"""`\\\\\\\\\')\n    return',
#   "def print_figure(face):\n    face() # Print the face\n    print('    |')\n    print('  --|--')\n    print(' /  |  \\\\\\\\')\n    print('@   |   @')\n    print('    |\\'')\n    print('   /|\\\\\\\\')\n    print('  @   @')\n    return",
#   'choice = int(input(\'Enter "1" to draw monkey, "2" for human:\'))\n\nif choice ==1:\n    print _ figure (print_monkey_head)\nelif choice == 2:\nprint _ figure (print_human_head)',
#   'choice = int(input(\'Enter "1" to draw monkey, "2" for human:\'))\n\nif choice ==1:\n    print_figure (print_monkey_head)\nelif choice == 2:\n    print_figure (print_human_head)',
#   'choice = int(input(\'Enter "1" to draw monkey, "2" for human:\'))\n\nif choice ==1:\n    print_figure (print_monkey_head)\nelif choice == 2:\n    print_figure (print_human_head)',
#   "centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input('Enter feet: '))\ni_inches = int(input( ' Enter inches:'))\n\nprint( 'Centimeters: ' , height_US_to_centimeters(i_feet,i_inches))",
#   "centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    print('Total inches: ', total_inches)\n    centimeters = total_inches * centimeters_per_inch\n    print('Centimeters: ', centimeters)\n    return centimeters\n\ni_feet = int(input('Enter feet: '))\nprint( 'Feet: ' , i_feet)\ni_inches = int(input( ' Enter inches:'))\nprint( 'Inches: ' , i_inches)\n\nprint( 'Centimeters: ' , height_US_to_centimeters(i_feet,i_inches))",
#   "centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    print('Total inches: ', total_inches)\n    centimeters = total_inches * centimeters_per_inch\n    print('Centimeters: ', centimeters)\n    return centimeters\n\ni_feet = int(input('Enter feet: '))\nprint( 'Feet: ' , i_feet)\ni_inches = int(input( ' Enter inches:'))\nprint( 'Inches: ' , i_inches)\nprint( 'Centimeters: ' , height_US_to_centimeters(i_feet,i_inches))",
#   "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    print( ' Employee name: ' , name)\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   "employee_name = 'N/A'\ndef get_name():\n    global employee_name\n    name = input('Enter employee name: ')\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   "employee_name = 'N/A'\ndef get_name():\n    global employee_name\n    name = input('Enter employee name: ')\n    print('Employee name: ', name)\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   'daily_cals = 2300 # Daily calories\nsoda_cals = 200\n\ndef drink_soda(cals_left):\n    return cals_left - soda_cals\ndaily_cals = drink_soda(daily_cals)\nprint(daily_cals)',
#   "employee_name = 'N/A'\n\n# 2. Define functions\ndef get_name1():\n    global employee_name\n    name = input('Enter employee name: ')\n    employee_name = name\n\n# 3. Call functions and run logic\nget_name1()\nprint('Employee name:', employee_name)",
#   "employee_name = 'N/A'\nget_name1()\nprint('Employee name:', employee_name)\ndef get_name1():\n    global employee_name\nname = input('Enter employee name:')\nemployee_name = name",
#   "employee_name = 'N/A'\nget_name1()\nprint('Employee name:', employee_name)\ndef get_name1():\n    global employee_name\n    name = input('Enter employee name:')\n    employee_name = name",
#   "employee_name = 'N/A'\nget_name1()\nprint('Employee name:', employee_name)\ndef get_name1():\n    global employee_name\n    name = input('Enter employee name:')\n    employee_name = name",
#   "employee_name = 'N/A'\nget_name2()\nprint('Employee name:', employee_name)\n\ndef get_name2():\n    global employee_name\n    name = input('Enter employee name:')\n    employee_name = name",
#   'daily_cals = 2300 # Daily calories\nsoda_cals = 200\n\ndef drink_soda(cals_left):\n    return cals_left - soda_cals\ndaily_cals = drink_soda(daily_cals)\nprint(daily_cals)',
#   "print('Initial global namespace: ')\nprint(globals())",
#   'my_var "This is a variable"\nprint(\'\\nCreated new variable\') print(globals())',
#   'my_var = "This is a variable"\nprint(\'\\nCreated new variable\') \nprint(globals())',
#   "def my_func():\n    pass\nprint('\\nCreated new function')\nprint(globals())",
#   "def my_func():\n    pass\nprint('\\nCreated new function')\nglobals()",
#   'my_var = "This is a variable"\nprint(\'\\nCreated new variable\') \nglobals()'],
#  '_oh': {27: {...}},
#  '_dh': [PosixPath('/workspaces/VIBE-Coding-with-Python')],
#  'In': ['',
#   "def print_human_head():\n    print(' ||||| ')\n    print(' ㅇㅇ')\n    print(' >')\n    print('\n    00000\n    return",
#   "def print_human_head():\n    print(' ||||| ')\n    print(' ㅇㅇ')\n    print(' >')\n    print('    00000')\n    return",
#   'def print_monkey_head():\n    print(\'.-"-.\')\n    print(\'/.-.-.\\\\_\')\n    print(\'((oo))\')\n    print(\'|/ " \\\\\\\')\n    print(\' \\\\.-./\')\n    print(\'/`"""`\\\\\')\n    return',
#   'def print_monkey_head():\n    print(\'  .-"-._ \')\n    print(\' _/.-.-.\\\\\\\\_\')\n    print(\'( ( o o ) )\')\n    print(\' |/  "  \\\\\\\\|\')\n    print(\'  \\\\\\\\ .-. / \')\n    print(\'  / `"""`\\\\\\\\\')\n    return',
#   "def print_figure(face):\n    face() # Print the face\n    print('    |')\n    print('  --|--')\n    print(' /  |  \\\\\\\\')\n    print('@   |   @')\n    print('    |\\'')\n    print('   /|\\\\\\\\')\n    print('  @   @')\n    return",
#   'choice = int(input(\'Enter "1" to draw monkey, "2" for human:\'))\n\nif choice ==1:\n    print _ figure (print_monkey_head)\nelif choice == 2:\nprint _ figure (print_human_head)',
#   'choice = int(input(\'Enter "1" to draw monkey, "2" for human:\'))\n\nif choice ==1:\n    print_figure (print_monkey_head)\nelif choice == 2:\n    print_figure (print_human_head)',
#   'choice = int(input(\'Enter "1" to draw monkey, "2" for human:\'))\n\nif choice ==1:\n    print_figure (print_monkey_head)\nelif choice == 2:\n    print_figure (print_human_head)',
#   "centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input('Enter feet: '))\ni_inches = int(input( ' Enter inches:'))\n\nprint( 'Centimeters: ' , height_US_to_centimeters(i_feet,i_inches))",
#   "centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    print('Total inches: ', total_inches)\n    centimeters = total_inches * centimeters_per_inch\n    print('Centimeters: ', centimeters)\n    return centimeters\n\ni_feet = int(input('Enter feet: '))\nprint( 'Feet: ' , i_feet)\ni_inches = int(input( ' Enter inches:'))\nprint( 'Inches: ' , i_inches)\n\nprint( 'Centimeters: ' , height_US_to_centimeters(i_feet,i_inches))",
#   "centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    print('Total inches: ', total_inches)\n    centimeters = total_inches * centimeters_per_inch\n    print('Centimeters: ', centimeters)\n    return centimeters\n\ni_feet = int(input('Enter feet: '))\nprint( 'Feet: ' , i_feet)\ni_inches = int(input( ' Enter inches:'))\nprint( 'Inches: ' , i_inches)\nprint( 'Centimeters: ' , height_US_to_centimeters(i_feet,i_inches))",
#   "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    print( ' Employee name: ' , name)\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   "employee_name = 'N/A'\ndef get_name():\n    global employee_name\n    name = input('Enter employee name: ')\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   "employee_name = 'N/A'\ndef get_name():\n    global employee_name\n    name = input('Enter employee name: ')\n    print('Employee name: ', name)\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   'daily_cals = 2300 # Daily calories\nsoda_cals = 200\n\ndef drink_soda(cals_left):\n    return cals_left - soda_cals\ndaily_cals = drink_soda(daily_cals)\nprint(daily_cals)',
#   "employee_name = 'N/A'\n\n# 2. Define functions\ndef get_name1():\n    global employee_name\n    name = input('Enter employee name: ')\n    employee_name = name\n\n# 3. Call functions and run logic\nget_name1()\nprint('Employee name:', employee_name)",
#   "employee_name = 'N/A'\nget_name1()\nprint('Employee name:', employee_name)\ndef get_name1():\n    global employee_name\nname = input('Enter employee name:')\nemployee_name = name",
#   "employee_name = 'N/A'\nget_name1()\nprint('Employee name:', employee_name)\ndef get_name1():\n    global employee_name\n    name = input('Enter employee name:')\n    employee_name = name",
#   "employee_name = 'N/A'\nget_name1()\nprint('Employee name:', employee_name)\ndef get_name1():\n    global employee_name\n    name = input('Enter employee name:')\n    employee_name = name",
#   "employee_name = 'N/A'\nget_name2()\nprint('Employee name:', employee_name)\n\ndef get_name2():\n    global employee_name\n    name = input('Enter employee name:')\n    employee_name = name",
#   'daily_cals = 2300 # Daily calories\nsoda_cals = 200\n\ndef drink_soda(cals_left):\n    return cals_left - soda_cals\ndaily_cals = drink_soda(daily_cals)\nprint(daily_cals)',
#   "print('Initial global namespace: ')\nprint(globals())",
#   'my_var "This is a variable"\nprint(\'\\nCreated new variable\') print(globals())',
#   'my_var = "This is a variable"\nprint(\'\\nCreated new variable\') \nprint(globals())',
#   "def my_func():\n    pass\nprint('\\nCreated new function')\nprint(globals())",
#   "def my_func():\n    pass\nprint('\\nCreated new function')\nglobals()",
#   'my_var = "This is a variable"\nprint(\'\\nCreated new variable\') \nglobals()'],
#  'Out': {27: {...}},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x729a181b4b60>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x729a18448500>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x729a18448500>,
#  'open': <function _io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
#  '_': {...},
#  '__': '',
#  '___': '',
#  '__vsc_ipynb_file__': '/workspaces/VIBE-Coding-with-Python/06_Functions.ipynb',
#  '_i': "def my_func():\n    pass\nprint('\\nCreated new function')\nglobals()",
#  '_ii': "def my_func():\n    pass\nprint('\\nCreated new function')\nprint(globals())",
#  '_iii': 'my_var = "This is a variable"\nprint(\'\\nCreated new variable\') \nprint(globals())',
#  '_i1': "def print_human_head():\n    print(' ||||| ')\n    print(' ㅇㅇ')\n    print(' >')\n    print('\n    00000\n    return",
#  '_i2': "def print_human_head():\n    print(' ||||| ')\n    print(' ㅇㅇ')\n    print(' >')\n    print('    00000')\n    return",
#  'print_human_head': <function __main__.print_human_head()>,
#  '_i3': 'def print_monkey_head():\n    print(\'.-"-.\')\n    print(\'/.-.-.\\\\_\')\n    print(\'((oo))\')\n    print(\'|/ " \\\\\\\')\n    print(\' \\\\.-./\')\n    print(\'/`"""`\\\\\')\n    return',
#  '_i4': 'def print_monkey_head():\n    print(\'  .-"-._ \')\n    print(\' _/.-.-.\\\\\\\\_\')\n    print(\'( ( o o ) )\')\n    print(\' |/  "  \\\\\\\\|\')\n    print(\'  \\\\\\\\ .-. / \')\n    print(\'  / `"""`\\\\\\\\\')\n    return',
#  'print_monkey_head': <function __main__.print_monkey_head()>,
#  '_i5': "def print_figure(face):\n    face() # Print the face\n    print('    |')\n    print('  --|--')\n    print(' /  |  \\\\\\\\')\n    print('@   |   @')\n    print('    |\\'')\n    print('   /|\\\\\\\\')\n    print('  @   @')\n    return",
#  'print_figure': <function __main__.print_figure(face)>,
#  '_i6': 'choice = int(input(\'Enter "1" to draw monkey, "2" for human:\'))\n\nif choice ==1:\n    print _ figure (print_monkey_head)\nelif choice == 2:\nprint _ figure (print_human_head)',
#  '_i7': 'choice = int(input(\'Enter "1" to draw monkey, "2" for human:\'))\n\nif choice ==1:\n    print_figure (print_monkey_head)\nelif choice == 2:\n    print_figure (print_human_head)',
#  'choice': 1,
#  '_i8': 'choice = int(input(\'Enter "1" to draw monkey, "2" for human:\'))\n\nif choice ==1:\n    print_figure (print_monkey_head)\nelif choice == 2:\n    print_figure (print_human_head)',
#  '_i9': "centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input('Enter feet: '))\ni_inches = int(input( ' Enter inches:'))\n\nprint( 'Centimeters: ' , height_US_to_centimeters(i_feet,i_inches))",
#  'centimeters_per_inch': 2.54,
#  'inches_per_foot': 12,
#  'height_US_to_centimeters': <function __main__.height_US_to_centimeters(feet, inches)>,
#  'i_feet': 5,
#  'i_inches': 5,
#  '_i10': "centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    print('Total inches: ', total_inches)\n    centimeters = total_inches * centimeters_per_inch\n    print('Centimeters: ', centimeters)\n    return centimeters\n\ni_feet = int(input('Enter feet: '))\nprint( 'Feet: ' , i_feet)\ni_inches = int(input( ' Enter inches:'))\nprint( 'Inches: ' , i_inches)\n\nprint( 'Centimeters: ' , height_US_to_centimeters(i_feet,i_inches))",
#  '_i11': "centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    print('Total inches: ', total_inches)\n    centimeters = total_inches * centimeters_per_inch\n    print('Centimeters: ', centimeters)\n    return centimeters\n\ni_feet = int(input('Enter feet: '))\nprint( 'Feet: ' , i_feet)\ni_inches = int(input( ' Enter inches:'))\nprint( 'Inches: ' , i_inches)\nprint( 'Centimeters: ' , height_US_to_centimeters(i_feet,i_inches))",
#  '_i12': "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#  'employee_name': 'N/A',
#  'get_name': <function __main__.get_name()>,
#  '_i13': "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    print( ' Employee name: ' , name)\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#  '_i14': "employee_name = 'N/A'\ndef get_name():\n    global employee_name\n    name = input('Enter employee name: ')\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#  '_i15': "employee_name = 'N/A'\ndef get_name():\n    global employee_name\n    name = input('Enter employee name: ')\n    print('Employee name: ', name)\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#  '_i16': 'daily_cals = 2300 # Daily calories\nsoda_cals = 200\n\ndef drink_soda(cals_left):\n    return cals_left - soda_cals\ndaily_cals = drink_soda(daily_cals)\nprint(daily_cals)',
#  'daily_cals': 2100,
#  'soda_cals': 200,
#  'drink_soda': <function __main__.drink_soda(cals_left)>,
#  '_i17': "employee_name = 'N/A'\n\n# 2. Define functions\ndef get_name1():\n    global employee_name\n    name = input('Enter employee name: ')\n    employee_name = name\n\n# 3. Call functions and run logic\nget_name1()\nprint('Employee name:', employee_name)",
#  'get_name1': <function __main__.get_name1()>,
#  '_i18': "employee_name = 'N/A'\nget_name1()\nprint('Employee name:', employee_name)\ndef get_name1():\n    global employee_name\nname = input('Enter employee name:')\nemployee_name = name",
#  'name': 'nikita',
#  '_i19': "employee_name = 'N/A'\nget_name1()\nprint('Employee name:', employee_name)\ndef get_name1():\n    global employee_name\n    name = input('Enter employee name:')\n    employee_name = name",
#  '_i20': "employee_name = 'N/A'\nget_name1()\nprint('Employee name:', employee_name)\ndef get_name1():\n    global employee_name\n    name = input('Enter employee name:')\n    employee_name = name",
#  '_i21': "employee_name = 'N/A'\nget_name2()\nprint('Employee name:', employee_name)\n\ndef get_name2():\n    global employee_name\n    name = input('Enter employee name:')\n    employee_name = name",
#  '_i22': 'daily_cals = 2300 # Daily calories\nsoda_cals = 200\n\ndef drink_soda(cals_left):\n    return cals_left - soda_cals\ndaily_cals = drink_soda(daily_cals)\nprint(daily_cals)',
#  '_i23': "print('Initial global namespace: ')\nprint(globals())",
#  '_i24': 'my_var "This is a variable"\nprint(\'\\nCreated new variable\') print(globals())',
#  '_i25': 'my_var = "This is a variable"\nprint(\'\\nCreated new variable\') \nprint(globals())',
#  'my_var': 'This is a variable',
#  '_i26': "def my_func():\n    pass\nprint('\\nCreated new function')\nprint(globals())",
#  'my_func': <function __main__.my_func()>,
#  '_i27': "def my_func():\n    pass\nprint('\\nCreated new function')\nglobals()",
#  '_27': {...},
#  '_i28': 'my_var = "This is a variable"\nprint(\'\\nCreated new variable\') \nglobals()'}

# %%
def my_func():
    pass
print('\nCreated new function')
globals()
# Out:
# Created new function
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   "def print_human_head():\n    print(' ||||| ')\n    print(' ㅇㅇ')\n    print(' >')\n    print('\n    00000\n    return",
#   "def print_human_head():\n    print(' ||||| ')\n    print(' ㅇㅇ')\n    print(' >')\n    print('    00000')\n    return",
#   'def print_monkey_head():\n    print(\'.-"-.\')\n    print(\'/.-.-.\\\\_\')\n    print(\'((oo))\')\n    print(\'|/ " \\\\\\\')\n    print(\' \\\\.-./\')\n    print(\'/`"""`\\\\\')\n    return',
#   'def print_monkey_head():\n    print(\'  .-"-._ \')\n    print(\' _/.-.-.\\\\\\\\_\')\n    print(\'( ( o o ) )\')\n    print(\' |/  "  \\\\\\\\|\')\n    print(\'  \\\\\\\\ .-. / \')\n    print(\'  / `"""`\\\\\\\\\')\n    return',
#   "def print_figure(face):\n    face() # Print the face\n    print('    |')\n    print('  --|--')\n    print(' /  |  \\\\\\\\')\n    print('@   |   @')\n    print('    |\\'')\n    print('   /|\\\\\\\\')\n    print('  @   @')\n    return",
#   'choice = int(input(\'Enter "1" to draw monkey, "2" for human:\'))\n\nif choice ==1:\n    print _ figure (print_monkey_head)\nelif choice == 2:\nprint _ figure (print_human_head)',
#   'choice = int(input(\'Enter "1" to draw monkey, "2" for human:\'))\n\nif choice ==1:\n    print_figure (print_monkey_head)\nelif choice == 2:\n    print_figure (print_human_head)',
#   'choice = int(input(\'Enter "1" to draw monkey, "2" for human:\'))\n\nif choice ==1:\n    print_figure (print_monkey_head)\nelif choice == 2:\n    print_figure (print_human_head)',
#   "centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input('Enter feet: '))\ni_inches = int(input( ' Enter inches:'))\n\nprint( 'Centimeters: ' , height_US_to_centimeters(i_feet,i_inches))",
#   "centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    print('Total inches: ', total_inches)\n    centimeters = total_inches * centimeters_per_inch\n    print('Centimeters: ', centimeters)\n    return centimeters\n\ni_feet = int(input('Enter feet: '))\nprint( 'Feet: ' , i_feet)\ni_inches = int(input( ' Enter inches:'))\nprint( 'Inches: ' , i_inches)\n\nprint( 'Centimeters: ' , height_US_to_centimeters(i_feet,i_inches))",
#   "centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    print('Total inches: ', total_inches)\n    centimeters = total_inches * centimeters_per_inch\n    print('Centimeters: ', centimeters)\n    return centimeters\n\ni_feet = int(input('Enter feet: '))\nprint( 'Feet: ' , i_feet)\ni_inches = int(input( ' Enter inches:'))\nprint( 'Inches: ' , i_inches)\nprint( 'Centimeters: ' , height_US_to_centimeters(i_feet,i_inches))",
#   "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    print( ' Employee name: ' , name)\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   "employee_name = 'N/A'\ndef get_name():\n    global employee_name\n    name = input('Enter employee name: ')\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   "employee_name = 'N/A'\ndef get_name():\n    global employee_name\n    name = input('Enter employee name: ')\n    print('Employee name: ', name)\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   'daily_cals = 2300 # Daily calories\nsoda_cals = 200\n\ndef drink_soda(cals_left):\n    return cals_left - soda_cals\ndaily_cals = drink_soda(daily_cals)\nprint(daily_cals)',
#   "employee_name = 'N/A'\n\n# 2. Define functions\ndef get_name1():\n    global employee_name\n    name = input('Enter employee name: ')\n    employee_name = name\n\n# 3. Call functions and run logic\nget_name1()\nprint('Employee name:', employee_name)",
#   "employee_name = 'N/A'\nget_name1()\nprint('Employee name:', employee_name)\ndef get_name1():\n    global employee_name\nname = input('Enter employee name:')\nemployee_name = name",
#   "employee_name = 'N/A'\nget_name1()\nprint('Employee name:', employee_name)\ndef get_name1():\n    global employee_name\n    name = input('Enter employee name:')\n    employee_name = name",
#   "employee_name = 'N/A'\nget_name1()\nprint('Employee name:', employee_name)\ndef get_name1():\n    global employee_name\n    name = input('Enter employee name:')\n    employee_name = name",
#   "employee_name = 'N/A'\nget_name2()\nprint('Employee name:', employee_name)\n\ndef get_name2():\n    global employee_name\n    name = input('Enter employee name:')\n    employee_name = name",
#   'daily_cals = 2300 # Daily calories\nsoda_cals = 200\n\ndef drink_soda(cals_left):\n    return cals_left - soda_cals\ndaily_cals = drink_soda(daily_cals)\nprint(daily_cals)',
#   "print('Initial global namespace: ')\nprint(globals())",
#   'my_var "This is a variable"\nprint(\'\\nCreated new variable\') print(globals())',
#   'my_var = "This is a variable"\nprint(\'\\nCreated new variable\') \nprint(globals())',
#   "def my_func():\n    pass\nprint('\\nCreated new function')\nprint(globals())",
#   "def my_func():\n    pass\nprint('\\nCreated new function')\nglobals()"],
#  '_oh': {},
#  '_dh': [PosixPath('/workspaces/VIBE-Coding-with-Python')],
#  'In': ['',
#   "def print_human_head():\n    print(' ||||| ')\n    print(' ㅇㅇ')\n    print(' >')\n    print('\n    00000\n    return",
#   "def print_human_head():\n    print(' ||||| ')\n    print(' ㅇㅇ')\n    print(' >')\n    print('    00000')\n    return",
#   'def print_monkey_head():\n    print(\'.-"-.\')\n    print(\'/.-.-.\\\\_\')\n    print(\'((oo))\')\n    print(\'|/ " \\\\\\\')\n    print(\' \\\\.-./\')\n    print(\'/`"""`\\\\\')\n    return',
#   'def print_monkey_head():\n    print(\'  .-"-._ \')\n    print(\' _/.-.-.\\\\\\\\_\')\n    print(\'( ( o o ) )\')\n    print(\' |/  "  \\\\\\\\|\')\n    print(\'  \\\\\\\\ .-. / \')\n    print(\'  / `"""`\\\\\\\\\')\n    return',
#   "def print_figure(face):\n    face() # Print the face\n    print('    |')\n    print('  --|--')\n    print(' /  |  \\\\\\\\')\n    print('@   |   @')\n    print('    |\\'')\n    print('   /|\\\\\\\\')\n    print('  @   @')\n    return",
#   'choice = int(input(\'Enter "1" to draw monkey, "2" for human:\'))\n\nif choice ==1:\n    print _ figure (print_monkey_head)\nelif choice == 2:\nprint _ figure (print_human_head)',
#   'choice = int(input(\'Enter "1" to draw monkey, "2" for human:\'))\n\nif choice ==1:\n    print_figure (print_monkey_head)\nelif choice == 2:\n    print_figure (print_human_head)',
#   'choice = int(input(\'Enter "1" to draw monkey, "2" for human:\'))\n\nif choice ==1:\n    print_figure (print_monkey_head)\nelif choice == 2:\n    print_figure (print_human_head)',
#   "centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input('Enter feet: '))\ni_inches = int(input( ' Enter inches:'))\n\nprint( 'Centimeters: ' , height_US_to_centimeters(i_feet,i_inches))",
#   "centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    print('Total inches: ', total_inches)\n    centimeters = total_inches * centimeters_per_inch\n    print('Centimeters: ', centimeters)\n    return centimeters\n\ni_feet = int(input('Enter feet: '))\nprint( 'Feet: ' , i_feet)\ni_inches = int(input( ' Enter inches:'))\nprint( 'Inches: ' , i_inches)\n\nprint( 'Centimeters: ' , height_US_to_centimeters(i_feet,i_inches))",
#   "centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    print('Total inches: ', total_inches)\n    centimeters = total_inches * centimeters_per_inch\n    print('Centimeters: ', centimeters)\n    return centimeters\n\ni_feet = int(input('Enter feet: '))\nprint( 'Feet: ' , i_feet)\ni_inches = int(input( ' Enter inches:'))\nprint( 'Inches: ' , i_inches)\nprint( 'Centimeters: ' , height_US_to_centimeters(i_feet,i_inches))",
#   "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    print( ' Employee name: ' , name)\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   "employee_name = 'N/A'\ndef get_name():\n    global employee_name\n    name = input('Enter employee name: ')\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   "employee_name = 'N/A'\ndef get_name():\n    global employee_name\n    name = input('Enter employee name: ')\n    print('Employee name: ', name)\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   'daily_cals = 2300 # Daily calories\nsoda_cals = 200\n\ndef drink_soda(cals_left):\n    return cals_left - soda_cals\ndaily_cals = drink_soda(daily_cals)\nprint(daily_cals)',
#   "employee_name = 'N/A'\n\n# 2. Define functions\ndef get_name1():\n    global employee_name\n    name = input('Enter employee name: ')\n    employee_name = name\n\n# 3. Call functions and run logic\nget_name1()\nprint('Employee name:', employee_name)",
#   "employee_name = 'N/A'\nget_name1()\nprint('Employee name:', employee_name)\ndef get_name1():\n    global employee_name\nname = input('Enter employee name:')\nemployee_name = name",
#   "employee_name = 'N/A'\nget_name1()\nprint('Employee name:', employee_name)\ndef get_name1():\n    global employee_name\n    name = input('Enter employee name:')\n    employee_name = name",
#   "employee_name = 'N/A'\nget_name1()\nprint('Employee name:', employee_name)\ndef get_name1():\n    global employee_name\n    name = input('Enter employee name:')\n    employee_name = name",
#   "employee_name = 'N/A'\nget_name2()\nprint('Employee name:', employee_name)\n\ndef get_name2():\n    global employee_name\n    name = input('Enter employee name:')\n    employee_name = name",
#   'daily_cals = 2300 # Daily calories\nsoda_cals = 200\n\ndef drink_soda(cals_left):\n    return cals_left - soda_cals\ndaily_cals = drink_soda(daily_cals)\nprint(daily_cals)',
#   "print('Initial global namespace: ')\nprint(globals())",
#   'my_var "This is a variable"\nprint(\'\\nCreated new variable\') print(globals())',
#   'my_var = "This is a variable"\nprint(\'\\nCreated new variable\') \nprint(globals())',
#   "def my_func():\n    pass\nprint('\\nCreated new function')\nprint(globals())",
#   "def my_func():\n    pass\nprint('\\nCreated new function')\nglobals()"],
#  'Out': {},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x729a181b4b60>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x729a18448500>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x729a18448500>,
#  'open': <function _io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
#  '_': '',
#  '__': '',
#  '___': '',
#  '__vsc_ipynb_file__': '/workspaces/VIBE-Coding-with-Python/06_Functions.ipynb',
#  '_i': "def my_func():\n    pass\nprint('\\nCreated new function')\nprint(globals())",
#  '_ii': 'my_var = "This is a variable"\nprint(\'\\nCreated new variable\') \nprint(globals())',
#  '_iii': 'my_var "This is a variable"\nprint(\'\\nCreated new variable\') print(globals())',
#  '_i1': "def print_human_head():\n    print(' ||||| ')\n    print(' ㅇㅇ')\n    print(' >')\n    print('\n    00000\n    return",
#  '_i2': "def print_human_head():\n    print(' ||||| ')\n    print(' ㅇㅇ')\n    print(' >')\n    print('    00000')\n    return",
#  'print_human_head': <function __main__.print_human_head()>,
#  '_i3': 'def print_monkey_head():\n    print(\'.-"-.\')\n    print(\'/.-.-.\\\\_\')\n    print(\'((oo))\')\n    print(\'|/ " \\\\\\\')\n    print(\' \\\\.-./\')\n    print(\'/`"""`\\\\\')\n    return',
#  '_i4': 'def print_monkey_head():\n    print(\'  .-"-._ \')\n    print(\' _/.-.-.\\\\\\\\_\')\n    print(\'( ( o o ) )\')\n    print(\' |/  "  \\\\\\\\|\')\n    print(\'  \\\\\\\\ .-. / \')\n    print(\'  / `"""`\\\\\\\\\')\n    return',
#  'print_monkey_head': <function __main__.print_monkey_head()>,
#  '_i5': "def print_figure(face):\n    face() # Print the face\n    print('    |')\n    print('  --|--')\n    print(' /  |  \\\\\\\\')\n    print('@   |   @')\n    print('    |\\'')\n    print('   /|\\\\\\\\')\n    print('  @   @')\n    return",
#  'print_figure': <function __main__.print_figure(face)>,
#  '_i6': 'choice = int(input(\'Enter "1" to draw monkey, "2" for human:\'))\n\nif choice ==1:\n    print _ figure (print_monkey_head)\nelif choice == 2:\nprint _ figure (print_human_head)',
#  '_i7': 'choice = int(input(\'Enter "1" to draw monkey, "2" for human:\'))\n\nif choice ==1:\n    print_figure (print_monkey_head)\nelif choice == 2:\n    print_figure (print_human_head)',
#  'choice': 1,
#  '_i8': 'choice = int(input(\'Enter "1" to draw monkey, "2" for human:\'))\n\nif choice ==1:\n    print_figure (print_monkey_head)\nelif choice == 2:\n    print_figure (print_human_head)',
#  '_i9': "centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input('Enter feet: '))\ni_inches = int(input( ' Enter inches:'))\n\nprint( 'Centimeters: ' , height_US_to_centimeters(i_feet,i_inches))",
#  'centimeters_per_inch': 2.54,
#  'inches_per_foot': 12,
#  'height_US_to_centimeters': <function __main__.height_US_to_centimeters(feet, inches)>,
#  'i_feet': 5,
#  'i_inches': 5,
#  '_i10': "centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    print('Total inches: ', total_inches)\n    centimeters = total_inches * centimeters_per_inch\n    print('Centimeters: ', centimeters)\n    return centimeters\n\ni_feet = int(input('Enter feet: '))\nprint( 'Feet: ' , i_feet)\ni_inches = int(input( ' Enter inches:'))\nprint( 'Inches: ' , i_inches)\n\nprint( 'Centimeters: ' , height_US_to_centimeters(i_feet,i_inches))",
#  '_i11': "centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    print('Total inches: ', total_inches)\n    centimeters = total_inches * centimeters_per_inch\n    print('Centimeters: ', centimeters)\n    return centimeters\n\ni_feet = int(input('Enter feet: '))\nprint( 'Feet: ' , i_feet)\ni_inches = int(input( ' Enter inches:'))\nprint( 'Inches: ' , i_inches)\nprint( 'Centimeters: ' , height_US_to_centimeters(i_feet,i_inches))",
#  '_i12': "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#  'employee_name': 'N/A',
#  'get_name': <function __main__.get_name()>,
#  '_i13': "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    print( ' Employee name: ' , name)\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#  '_i14': "employee_name = 'N/A'\ndef get_name():\n    global employee_name\n    name = input('Enter employee name: ')\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#  '_i15': "employee_name = 'N/A'\ndef get_name():\n    global employee_name\n    name = input('Enter employee name: ')\n    print('Employee name: ', name)\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#  '_i16': 'daily_cals = 2300 # Daily calories\nsoda_cals = 200\n\ndef drink_soda(cals_left):\n    return cals_left - soda_cals\ndaily_cals = drink_soda(daily_cals)\nprint(daily_cals)',
#  'daily_cals': 2100,
#  'soda_cals': 200,
#  'drink_soda': <function __main__.drink_soda(cals_left)>,
#  '_i17': "employee_name = 'N/A'\n\n# 2. Define functions\ndef get_name1():\n    global employee_name\n    name = input('Enter employee name: ')\n    employee_name = name\n\n# 3. Call functions and run logic\nget_name1()\nprint('Employee name:', employee_name)",
#  'get_name1': <function __main__.get_name1()>,
#  '_i18': "employee_name = 'N/A'\nget_name1()\nprint('Employee name:', employee_name)\ndef get_name1():\n    global employee_name\nname = input('Enter employee name:')\nemployee_name = name",
#  'name': 'nikita',
#  '_i19': "employee_name = 'N/A'\nget_name1()\nprint('Employee name:', employee_name)\ndef get_name1():\n    global employee_name\n    name = input('Enter employee name:')\n    employee_name = name",
#  '_i20': "employee_name = 'N/A'\nget_name1()\nprint('Employee name:', employee_name)\ndef get_name1():\n    global employee_name\n    name = input('Enter employee name:')\n    employee_name = name",
#  '_i21': "employee_name = 'N/A'\nget_name2()\nprint('Employee name:', employee_name)\n\ndef get_name2():\n    global employee_name\n    name = input('Enter employee name:')\n    employee_name = name",
#  '_i22': 'daily_cals = 2300 # Daily calories\nsoda_cals = 200\n\ndef drink_soda(cals_left):\n    return cals_left - soda_cals\ndaily_cals = drink_soda(daily_cals)\nprint(daily_cals)',
#  '_i23': "print('Initial global namespace: ')\nprint(globals())",
#  '_i24': 'my_var "This is a variable"\nprint(\'\\nCreated new variable\') print(globals())',
#  '_i25': 'my_var = "This is a variable"\nprint(\'\\nCreated new variable\') \nprint(globals())',
#  'my_var': 'This is a variable',
#  '_i26': "def my_func():\n    pass\nprint('\\nCreated new function')\nprint(globals())",
#  'my_func': <function __main__.my_func()>,
#  '_i27': "def my_func():\n    pass\nprint('\\nCreated new function')\nglobals()"}

# %% [markdown]
# ### Scope resolutions

# %%
daily_cals = 2300 # Daily calories
soda_cals = 200

def drink_soda(cals_left):
    return cals_left - soda_cals
daily_cals = drink_soda(daily_cals)
print(daily_cals)
# Out:
# 2100

# %% [markdown]
# ### More scoping and namespaces

# %%
def avg(a, b):
    tmp = (a+b)/2.0
    return tmp
a = 5
b = 10
tmp = a+b

print(f'Avg: {avg(a, b): f}' )
print(f' Sum: {tmp:f}')
# Out:
# Avg:  7.500000
#  Sum: 15.000000

# %%
def avg(a, b):
    tmp = (a+b)/2.0
    print(locals())
    return tmp
a = 5
b = 10
tmp = a + b # Creates tmp in global namespace

print(f'Avg: {avg(a,b):f}' )
print(f'Sum: {tmp:f}')
print(globals())
# Out:
# {'a': 5, 'b': 10, 'tmp': 7.5}
# Avg: 7.500000
# Sum: 15.000000
# {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, '__loader__': None, '__spec__': None, '__builtin__': <module 'builtins' (built-in)>, '__builtins__': <module 'builtins' (built-in)>, '_ih': ['', "def print_human_head():\n    print(' ||||| ')\n    print(' ㅇㅇ')\n    print(' >')\n    print('\n    00000\n    return", "def print_human_head():\n    print(' ||||| ')\n    print(' ㅇㅇ')\n    print(' >')\n    print('    00000')\n    return", 'def print_monkey_head():\n    print(\'.-"-.\')\n    print(\'/.-.-.\\\\_\')\n    print(\'((oo))\')\n    print(\'|/ " \\\\\\\')\n    print(\' \\\\.-./\')\n    print(\'/`"""`\\\\\')\n    return', 'def print_monkey_head():\n    print(\'  .-"-._ \')\n    print(\' _/.-.-.\\\\\\\\_\')\n    print(\'( ( o o ) )\')\n    print(\' |/  "  \\\\\\\\|\')\n    print(\'  \\\\\\\\ .-. / \')\n    print(\'  / `"""`\\\\\\\\\')\n    return', "def print_figure(face):\n    face() # Print the face\n    print('    |')\n    print('  --|--')\n    print(' /  |  \\\\\\\\')\n    print('@   |   @')\n    print('    |\\'')\n    print('   /|\\\\\\\\')\n    print('  @   @')\n    return", 'choice = int(input(\'Enter "1" to draw monkey, "2" for human:\'))\n\nif choice ==1:\n    print _ figure (print_monkey_head)\nelif choice == 2:\nprint _ figure (print_human_head)', 'choice = int(input(\'Enter "1" to draw monkey, "2" for human:\'))\n\nif choice ==1:\n    print_figure (print_monkey_head)\nelif choice == 2:\n    print_figure (print_human_head)', 'choice = int(input(\'Enter "1" to draw monkey, "2" for human:\'))\n\nif choice ==1:\n    print_figure (print_monkey_head)\nelif choice == 2:\n    print_figure (print_human_head)', "centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input('Enter feet: '))\ni_inches = int(input( ' Enter inches:'))\n\nprint( 'Centimeters: ' , height_US_to_centimeters(i_feet,i_inches))", "centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    print('Total inches: ', total_inches)\n    centimeters = total_inches * centimeters_per_inch\n    print('Centimeters: ', centimeters)\n    return centimeters\n\ni_feet = int(input('Enter feet: '))\nprint( 'Feet: ' , i_feet)\ni_inches = int(input( ' Enter inches:'))\nprint( 'Inches: ' , i_inches)\n\nprint( 'Centimeters: ' , height_US_to_centimeters(i_feet,i_inches))", "centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    print('Total inches: ', total_inches)\n    centimeters = total_inches * centimeters_per_inch\n    print('Centimeters: ', centimeters)\n    return centimeters\n\ni_feet = int(input('Enter feet: '))\nprint( 'Feet: ' , i_feet)\ni_inches = int(input( ' Enter inches:'))\nprint( 'Inches: ' , i_inches)\nprint( 'Centimeters: ' , height_US_to_centimeters(i_feet,i_inches))", "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)", "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    print( ' Employee name: ' , name)\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)", "employee_name = 'N/A'\ndef get_name():\n    global employee_name\n    name = input('Enter employee name: ')\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)", "employee_name = 'N/A'\ndef get_name():\n    global employee_name\n    name = input('Enter employee name: ')\n    print('Employee name: ', name)\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , emplo ...

# %% [markdown]
# ### Assignments to parameters have no effect outside the function

# %%
def birthday(age):
    age = age + 1
    return age

timmy_age = 7
print (birthday (timmy_age) )
print('Timmy_age: ', timmy_age)
# Out:
# 8
# Timmy_age:  7

# %% [markdown]
# ### Keyword arguments

# %%
def print_book_description (title, author, publisher, year, version, num_chapters, num_pages):
    print('Title:',title)
    print('Author', author)
    print('Publisher', publisher)
    print('Year', year)
    print('Version', version)
    print(f'Number of chapters: {num_chapters}')
    print(f'Number of pages: {num_pages}')

# %%
# Call the function with arguments
print_book_description('The Lord of Rings', 'J. R. R. Tolkien', 'George Allen & Unwin',1954, 1.0, 22, 456)
# Out:
# Title: The Lord of Rings
# Author J. R. R. Tolkien
# Publisher George Allen & Unwin
# Year 1954
# Version 1.0
# Number of chapters: 22
# Number of pages: 456

# %%
# call the function with keyword arguments
print_book_description (title='The Lord of Rings', publisher= 'George Allen & Unwin', year=1954, author='J. R. R. Tolkien',version=1.0, num_chapters=22, num_pages=456)
# Out:
# Title: The Lord of Rings
# Author J. R. R. Tolkien
# Publisher George Allen & Unwin
# Year 1954
# Version 1.0
# Number of chapters: 22
# Number of pages: 456

# %%
def split_check(amount, num_people, tax_percentage, tip_percentage):
    total_bill = amount * (1 + tax_percentage) * (1 + tip_percentage)
    per_person = total_bill / num_people
    return per_person
split_check(125.00, 2, 0.095, tip_percentage=0.15)
# Out:
# 78.703125

# %%
def split_check(amount, num_people, tax_percentage, tip_percentage):
    total_bill = amount * (1 + tax_percentage) * (1 + tip_percentage)
    per_person = total_bill / num_people
    return per_person
split_check(125.00, 2, tip_percentage=0.15,tax_percentage=0.095 )
# Out:
# 78.703125

# %%
def print_date(day, month, year, style=0) :
  if style == 0: # American
    print(month, ' / ',day,'/',year)
  elif(style == 1): # European
    print(day, '/' ,month, '/' , year)
  else:
    print( 'Invalid Code')

# %%
print_date(30,7,2012,0)
print_date(30,7, 2012, 1)
print_date(30,7,2012) # style arguments not provivded! Default value of e used.
# Out:
# 7  /  30 / 2012
# 30 / 7 / 2012
# 7  /  30 / 2012

# %% [markdown]
# ### Mixing keywords and arguments

# %%
def print_date(day=1, month=1, year=2000, style=0):
    if style == 0:
        print(f"{day}/{month}/{year}")
    else:
        print(f"{year}-{month}-{day}")
day=1
month=1
year=2000
print_date(day, month, year)
# Out:
# 1/1/2000

# %%
print_date(day=30, year=2012)
print_date(style=1)
# Out:
# 30/1/2012
# 2000-1-1

# %% [markdown]
# ### Arbitary argument list

# %%
def print_sandwich (bread, slice, *args):
    print(f'Arbitary arguments are: {args}')
    print(f' {slice} on {bread}' , end='')
    if len(args) > 0:
       print( 'with', end='')
    for extra in args:
        print(extra, end='')
    print('')

# %%
print_sandwich('sourdough', 'kabab', 'mayo')
print_sandwich('wheat', 'paneer', 'mustard', 'tomato', 'lettuce')
# Out:
# Arbitary arguments are: ('mayo',)
#  kabab on sourdoughwithmayo
# Arbitary arguments are: ('mustard', 'tomato', 'lettuce')
#  paneer on wheatwithmustardtomatolettuce

# %%
def print_sandwich (bread, slice, **kwargs):
    print('The keyword Arguments are:', kwargs)
    print(f'{slice} on {bread}')
    for category, extra in kwargs.items():
        print(f'{category}: {extra}')
print()
print_sandwich('sourdough', 'kabab', sauce='mayo')
print_sandwich('wheat', 'paneer', sauce1='mustard', veggiel='tomato', veggie2='lettuce')
# Out:
# The keyword Arguments are: {'sauce': 'mayo'}
# kabab on sourdough
# sauce: mayo
# The keyword Arguments are: {'sauce1': 'mustard', 'veggiel': 'tomato', 'veggie2': 'lettuce'}
# paneer on wheat
# sauce1: mustard
# veggiel: tomato
# veggie2: lettuce

# %% [markdown]
# ### Multiple function outputs

# %%
student_scores = [75, 84, 66, 99, 51, 65]

def get_grade_stats(scores):
    mean = sum(scores)/len(scores)

    tmp = 0
    for score in scores:
        tmp += (score - mean)**2
    std_dev = (tmp/len(scores))**0.5
    return mean, std_dev

average, standard_deviation = get_grade_stats(student_scores)

print( 'Average score: ' , average)
print( 'Standard deviation: ' , standard_deviation)
# Out:
# Average score:  73.33333333333333
# Standard deviation:  15.260697523012796
