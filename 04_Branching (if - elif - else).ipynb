# %%
hotel_rate = 150

num_years = int(input('Enter years married'))
print(f'You have been married for {num_years} years.')

if num_years == 50:
    print('congratulations on 50 years of marriage!')
    hotel_rate = hotel_rate / 2

print(f'Your hotel rate: ${hotel_rate:,.2f}')
# Out:
# You have been married for 50 years.
# congratulations on 50 years of marriage!
# Your hotel rate: $75.00

# %%
user_num = int(input('Enter a number: '))

div_remainder = user_num % 2

if div_remainder ==  0:

   print(f'{user_num} is even.')
else:
   print(f'{user_num} is odd. ')
# Out:
# 5 is odd.

# %%
user_num = int(input(' Enter a number: '))

div_remainder = user_num % 2

if div_remainder == 0:
    print(f' {user_num} is even. ')
else:
    print(f' {user_num} is odd. ')
# Out:
#  89 is odd.

# %%
#multi-branch anniversary example using if-elif-else
years_married = int(input("Enter the number of years married: "))

if years_married == 1:
    print("First year down! Keep building that foundation.")
elif years_married == 5:
    print("Five years! You're deeply rooted now.")
elif years_married == 10:
    print("A decade together! Strong and resilient.")
elif years_married == 25:
    print("Quarter of a century! An amazing milestone.")
elif years_married == 50:
    print("The Golden Anniversary! Half a century of love.")
else:
    print(f"Happy {years_married}th Anniversary! Cheers to another great year.")

print(f"--- {years_married} Year Anniversary ---")
# Out:
# A decade together! Strong and resilient.
# --- 10 Year Anniversary ---

# %% [markdown]
# ### Ranges_with_branches

# %%
user_age = int(input('Enter your age:'))

if user_age < 16:           # Age 15 and under
    print( 'TOO young.')
    insurance_price = 0

elif user_age < 25:         #Age 16 - 24
    insurance_price = 4800

elif user_age < 40:         #Age 25 - 39
    insurance_price = 2350

else:
    insurance_price = 2100

print( 'Annual price: $', insurance_price)
# Out:
# Annual price: $ 2350

# %%
user_age = int(input( 'Enter your age: ' ))

if user_age < 16 :     # Age 15 and under
   print('Too young.')
   insurance_price = 0

elif user_age < 25:      #Age 16 - 24
   insurance_price = 4800

elif user_age < 40:      #Age 25 - 39
   insurance_price = 2350

else :                   #Age 40 and up
     insurance_price = 2100

print( 'Annual price: $', insurance_price)
# Out:
# Annual price: $ 4800

# %% [markdown]
# ### Evaluating expression with logical operator

# %%
my_bool = True # Assigns my_booL with the boolean value True
print (my_bool)
# Out:
# True

# %%
my_val= int(input( 'Enter a number: '))

is_small = my_val < 3 #Assign is_small with the result of the expression
print(is_small)
# Out:
# False is less than 3

# %%
user_channel = int(input('Enter channel number:'))

if (user_channel >= 2) and (user_channel <=499):
    channel_type = 's'
elif (user_channel >= 1002) and (user_channel <= 1499) :
    channel_type = 'h'
else :
    channel_type = 'e'
print( 'Channel Type: ' , channel_type)
# Out:
# Channel Type:  e

# %%
user_channel = int(input('Enter channel number:'))

if (user_channel >= 2) and (user_channel <=499):
    channel_type = 's'
elif (user_channel >= 1002) and (user_channel <= 1499) :
    channel_type = 'h'
else :
    channel_type = 'e'
print( 'Channel Type: ' , channel_type)
# Out:
# Channel Type:  s

# %%
user_channel = int(input('Enter channel number:'))

if (user_channel >= 2) and (user_channel <=499):
    channel_type = 's'
elif (user_channel >= 1002) and (user_channel <= 1499) :
    channel_type = 'h'
else :
    channel_type = 'e'
print( 'Channel Type: ' , channel_type)
# Out:
# Channel Type:  h

# %%
x = int(input('Enter the value of x:'))
if x < 0 :
   print( ' Negative ' ) # Negative

elif (x >= 0) and (x <=10) :
   print('0..10')

elif (x >= 11) and (x <= 20):
   print('11..20')

else:
   print('21+')
# Out:
# 0..10

# %%
x = int(input('Enter the valueof x:'))
if x < 0 :
     print( ' Negative ' )
elif (x <=10) :       # x>0 is implicit
     print('0..10')
elif (x <= 20) :
     print('11..20')
else:
     print('21+')
# Out:
# 11..20

# %%
x = int(input('Enter the value Of x : ' ) )
if x < 0 :
    print( ' Negative ' )
# Negative

elif (x >= 0) and (x <= 10):
    print(' 0..10')

elif (x>= 11) and (x <= 20) :
    print('11. .20')

else:
    print('21+')
# Out:
# 21+

# %%
x = int(input('Enter the value Of x: ' ) )
if x < 0 :
   print( 'Negative' )
elif (x <=10) :      # x>=0 is implicit
   print('0..10')
elif (x <= 20) :     # x > 10 is implicit
   print('11..20')
else :              # x>20 is implicit
   print('21+')
# Out:
# 21+

# %%
movie ticket_price = None
user_age =int(input('Enter your age:') )
if user_age <= 12:     # Age 12 and under
print( 'Child ticket discount. ' )
movie_ticket_price = 11
elif user_age >= 65:   # Age 65 and older
print( 'senior ticket discount.' )
movie_ticket_price = 12
else:
  movie_ticket_price = 14
print(f'Movie ticket price: {movie_ticket_price}')

# %%
movie_ticket_price = None
user_age = int(input('Enter your age: ' ) )
if user_age <=  12:    # Age 12 and under
    print( 'Child ticket discount. ')
    movie ticket_price = 11
elif user_age >= 65:   # Age 65 and older
    print( 'Senior ticket discount.,)
    movie_ticket_price = 12
else:
     movie_ticket_price = 14
print(f'Movie ticket price: ) {movie_ticket_price}')

# %%
office_num =int(input('Enter the office number: ' ) )

if office_num >= 100 and office_num <= 150:
    print( 'valid office number')
elif office_num >= 200 and office_num <= 250:
    print( 'valid office number')
else:
    print( 'invalid office number')

# %%
office_num = int(input( 'Enter office number:\n'))
if (office_num >= 100 and office_num <= 150) or(office_num >= 200 andoffice_num <= 250):
         print('valid office number')
else :
         print( ' invalid office number')

# %%
user_age = int(input('Enter age: '))
# Note that mre than one "if" statement can execute
if user_age < 16:
     print(' Enjoy your early years.')
if user _ age > 15:
     print( 'you are old enough to drive.')

if user _ age > 17:
     print('You are old enough to vote. ')

if user age > 24:
     print( 'Most car rental companies will rent to you.')
if user _ age > 34:
     print('You can run for president. ' )

# %%
x = 30
y = 10
if x >= y:
print( "x is greater than or equals to y")
if x == y:
   print("x is equals to y")
else:
    print("x is greater than y")
else:
    print("x is less than y")

# %%
#Use the "in" operator
barcelona_fc_roster = ['Alves', 'Messi', 'Fabregas']

name = input('Enter name to check:')

if name in barcelona_fc_roster:
     print( ' Found ' , name, 'on the roster.')
else:
     print( 'could not find' , name, 'on the roster. ')

# %%
request str = 'GET index.html HTTP/1.1'

if '/1.1' in request_str:
    print( 'HTTP protocol 1.1')
if 'HTTPS' not in request_str:
print( 'Unsecured connection')

# %%
my_dict = {'A':1,'B':2,'C':3}
if 'B ' in my_dict:
    print ("'B not found")

# Membership operator does not check values
if 3 in my_dict:
    print('Found 3')
else :
print('3 not found')

# %%
w=5øø
x=5øø+50       # create a new object with value 1000
y W+W          # Create a second object with value 1000

if z is x:
     print('z and x are bound to the same object')
if z is not y:
print('z and y are NOT bound to the sarne object')

# %%
# First code block has no indentation
model = input('Enter car model:')
year = int(input('Enter year of car manufacture'))

antique = False
domestic = False

if year < 1970:
# New code block has indentation of 4 columns
antique = True

# Back to code block O

if model in ['Ford','Chevrolet', 'Dodge']:
# New code block has indentation of 2 columns
# Any amount of indentation > O is 0K.
domestic = True

# Back to code block 0

if antique:
# New code block has indentation of 4 columns
if domestic:
# New block has 4 additional columns (8 total)
print( 'My own model-T still runs like a charm...')

# %%
num users = int(input())
update_direction = int(input())

num users
= num users + 1 if update direction
3 else num users
print( 'New value is:
num users)
